# %%
import os
import cv2
import pickle
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator

# %%
import os
import numpy as np
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras import optimizers
from keras.preprocessing import image
from PIL import Image,ImageOps
import cv2
import matplotlib.pyplot as plt
import tensorflow
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, BatchNormalization, ReLU, ELU, Dropout, Conv2D, Dense, MaxPool2D, AvgPool2D, GlobalAvgPool2D, Concatenate
import tensorflow as tf
import tensorflow.keras

from tensorflow.keras import models, layers
from tensorflow.keras.models import Model, model_from_json, Sequential

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, SeparableConv2D, UpSampling2D, BatchNormalization, Input, GlobalAveragePooling2D

from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, RMSprop
from tensorflow.keras.utils import to_categorical

# %%
DATA_DIR = '/content/drive/MyDrive/Crop_Disease/Data(CD)'
TRAIN_DATA_DIR = os.path.join(DATA_DIR, 'train')
TEST_DATA_DIR = os.path.join(DATA_DIR, 'valid')

# %%
IMG_SIZE = 128
CATEGORIES = []
for i in os.listdir(TRAIN_DATA_DIR):
    CATEGORIES.append(i)
print(CATEGORIES)
# Out:
# ['Rice___Brown_Spot', 'Corn___Common_Rust', 'Rice___Healthy', 'Corn___Healthy', 'Potato___Late_Blight', 'Potato___Healthy']

# %%
classes = len(CATEGORIES)
classes
# Out:
# 6

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

plt.figure(figsize=(15, 10), facecolor='white')
i = 1
num_images_per_class = 10

for c in CATEGORIES:
    path = os.path.join(TRAIN_DATA_DIR, c)
    image_list = os.listdir(path)
    if len(image_list) < num_images_per_class:
        continue
    random.shuffle(image_list)
    image_list = image_list[:num_images_per_class]

    for img_name in image_list:
        img_array = cv2.imread(os.path.join(path, img_name))
        img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        white_background = 255 * np.ones_like(img_array)

        x_offset = (white_background.shape[1] - img_array.shape[1]) // 2
        y_offset = (white_background.shape[0] - img_array.shape[0]) // 2
        white_background[y_offset:y_offset + img_array.shape[0], x_offset:x_offset + img_array.shape[1]] = img_array

        plt.subplot(len(CATEGORIES), num_images_per_class, i)
        plt.imshow(white_background)

        if i % num_images_per_class == 1:
            plt.title(c, color='red')

        plt.xticks([])
        plt.yticks([])
        i += 1

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
category_counts = {}
for category in CATEGORIES:
    category_path = os.path.join(TRAIN_DATA_DIR, category)
    num_images = len(os.listdir(category_path))
    category_counts[category] = num_images


plt.figure(figsize=(10, 6), facecolor='white')
plt.pie(category_counts.values(), labels=category_counts.keys(), autopct='%1.1f%%', startangle=140)
plt.title('Dataset Distribution (Pie Chart)')
plt.axis('equal')
plt.show()

plt.figure(figsize=(10, 6))
plt.bar(category_counts.keys(), category_counts.values())
plt.xlabel('Categories')
plt.ylabel('Number of Images')
plt.title('Dataset Distribution (Bar Chart)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
training_data = []

for c in CATEGORIES:
    path = os.path.join(TRAIN_DATA_DIR, c)
    class_num = CATEGORIES.index(c)
    for img in tqdm(os.listdir(path)):
        try:
            img_array = cv2.imread(os.path.join(path, img))
            img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
            training_data.append([img_resized, class_num])
        except Exception as e:
            pass

print(len(training_data))
# Out:
# 100%|██████████| 800/800 [01:45<00:00,  7.56it/s]
# 100%|██████████| 800/800 [00:03<00:00, 243.41it/s]
# 100%|██████████| 800/800 [01:48<00:00,  7.35it/s]
# 100%|██████████| 800/800 [00:02<00:00, 274.56it/s]
# 100%|██████████| 800/800 [00:03<00:00, 265.62it/s]
# 100%|██████████| 800/800 [00:03<00:00, 230.99it/s]
# 4800

# %%
test_data = []

for c in CATEGORIES:
    path = os.path.join(TEST_DATA_DIR, c)
    class_num = CATEGORIES.index(c)
    for img in tqdm(os.listdir(path)):
        try:
            img_array = cv2.imread(os.path.join(path, img))
            img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
            test_data.append([img_resized, class_num])
        except Exception as e:
            pass

print(len(test_data))
# Out:
# 100%|██████████| 200/200 [00:38<00:00,  5.22it/s]
# 100%|██████████| 200/200 [00:00<00:00, 257.08it/s]
# 100%|██████████| 200/200 [00:29<00:00,  6.88it/s]
# 100%|██████████| 200/200 [00:00<00:00, 276.50it/s]
# 100%|██████████| 200/200 [00:00<00:00, 245.24it/s]
# 100%|██████████| 200/200 [00:00<00:00, 255.17it/s]
# 1200

# %%
X_train = []
Y_train = []

for img, label in training_data:
    X_train.append(img)
    Y_train.append(label)

X_train = np.array(X_train).astype('float32').reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y_train = np.array(Y_train)

print(f"X_train= {X_train.shape} Y_train= {Y_train.shape}")
# Out:
# X_train= (4800, 128, 128, 3) Y_train= (4800,)

# %%
X_test = []
Y_test = []

for features,label in test_data:
    X_test.append(features)
    Y_test.append(label)

X_test = np.array(X_test).astype('float32').reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y_test = np.array(Y_test)

print(f"X_test= {X_test.shape} Y_test= {Y_test.shape}")
X_train, X_test = X_train / 255.0, X_test / 255.0
# Out:
# X_test= (1200, 128, 128, 3) Y_test= (1200,)

# %% [markdown]
# Efficientnet

# %%
# !pip install -q efficientnet

# %% [markdown]
# ### Enet B0

# %%
import efficientnet.tfkeras as efn

enet = efn.EfficientNetB0(
    input_shape=(128, 128, 3),
    weights='imagenet',
    include_top=False
)

for layer in loaded_model.layers:
        layer.trainable = False

x = enet.output
x = tf.keras.layers.GlobalMaxPooling2D()(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.5)(x)
y = tf.keras.layers.Dense(classes, activation='softmax')(x)

e_model_b0= tf.keras.Model(inputs=enet.input, outputs=y)
e_model_b0.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=5e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
efficientnet_b0 = e_model_b0.fit(x=X_train, y=Y_train, epochs=100, validation_data=(X_test, Y_test), batch_size=64)
# Out:
# Epoch 1/100
# 75/75 [==============================] - 66s 241ms/step - loss: 0.3125 - accuracy: 0.8933 - val_loss: 0.4738 - val_accuracy: 0.7933
# Epoch 2/100
# 75/75 [==============================] - 13s 178ms/step - loss: 0.1158 - accuracy: 0.9604 - val_loss: 0.3354 - val_accuracy: 0.8608
# Epoch 3/100
# 75/75 [==============================] - 13s 172ms/step - loss: 0.0812 - accuracy: 0.9744 - val_loss: 0.1795 - val_accuracy: 0.9267
# Epoch 4/100
# 75/75 [==============================] - 14s 190ms/step - loss: 0.0603 - accuracy: 0.9800 - val_loss: 0.1360 - val_accuracy: 0.9517
# Epoch 5/100
# 75/75 [==============================] - 16s 210ms/step - loss: 0.0486 - accuracy: 0.9833 - val_loss: 0.0966 - val_accuracy: 0.9692
# Epoch 6/100
# 75/75 [==============================] - 13s 179ms/step - loss: 0.0367 - accuracy: 0.9867 - val_loss: 0.0747 - val_accuracy: 0.9767
# Epoch 7/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0403 - accuracy: 0.9862 - val_loss: 0.0751 - val_accuracy: 0.9783
# Epoch 8/100
# 75/75 [==============================] - 13s 175ms/step - loss: 0.0206 - accuracy: 0.9929 - val_loss: 0.0593 - val_accuracy: 0.9867
# Epoch 9/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.0731 - val_accuracy: 0.9817
# Epoch 10/100
# 75/75 [==============================] - 14s 182ms/step - loss: 0.0162 - accuracy: 0.9948 - val_loss: 0.0345 - val_accuracy: 0.9883
# Epoch 11/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0521 - val_accuracy: 0.9858
# Epoch 12/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.0874 - val_accuracy: 0.9733
# Epoch 13/100
# 75/75 [==============================] - 14s 181ms/step - loss: 0.0193 - accuracy: 0.9944 - val_loss: 0.0583 - val_accuracy: 0.9850
# Epoch 14/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0131 - accuracy: 0.9954 - val_loss: 0.0830 - val_accuracy: 0.9800
# Epoch 15/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0149 - accuracy: 0.9962 - val_loss: 0.0889 - val_accuracy: 0.9733
# Epoch 16/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0136 - accuracy: 0.9965 - val_loss: 0.0457 - val_accuracy: 0.9867
# Epoch 17/100
# 75/75 [==============================] - 14s 182ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0478 - val_accuracy: 0.9850
# Epoch 18/100
# 75/75 [==============================] - 13s 175ms/step - loss: 0.0076 - accuracy: 0.9971 - val_loss: 0.1078 - val_accuracy: 0.9775
# Epoch 19/100
# 75/75 [==============================] - 14s 182ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 0.1415 - val_accuracy: 0.9792
# Epoch 20/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0613 - val_accuracy: 0.9833
# Epoch 21/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.1145 - val_accuracy: 0.9833
# Epoch 22/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0120 - accuracy: 0.9969 - val_loss: 0.0748 - val_accuracy: 0.9858
# Epoch 23/100
# 75/75 [==============================] - 14s 182ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 0.0782 - val_accuracy: 0.9883
# Epoch 24/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.0449 - val_accuracy: 0.9900
# Epoch 25/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0849 - val_accuracy: 0.9833
# Epoch 26/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0312 - val_accuracy: 0.9917
# Epoch 27/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.0199 - accuracy: 0.9944 - val_loss: 0.0320 - val_accuracy: 0.9900
# Epoch 28/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.0375 - val_accuracy: 0.9908
# Epoch 29/100
# 75/75 [==============================] - 13s 175ms/step - loss: 0.0157 - accuracy: 0.9952 - val_loss: 0.0456 - val_accuracy: 0.9875
# Epoch 30/100
# 75/75 [==============================] - 13s 179ms/step - loss: 0.0150 - accuracy: 0.9948 - val_loss: 0.1380 - val_accuracy: 0.9717
# Epoch 31/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0166 - accuracy: 0.9950 - val_loss: 0.0565 - val_accuracy: 0.9867
# Epoch 32/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0342 - val_accuracy: 0.9917
# Epoch 33/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 0.0787 - val_accuracy: 0.9875
# Epoch 34/100
# 75/75 [==============================] - 14s 182ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0331 - val_accuracy: 0.9925
# Epoch 35/100
# 75/75 [==============================] - 14s 182ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.0363 - val_accuracy: 0.9908
# Epoch 36/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.1026 - val_accuracy: 0.9850
# Epoch 37/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 0.0730 - val_accuracy: 0.9833
# Epoch 38/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0762 - val_accuracy: 0.9817
# Epoch 39/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0777 - val_accuracy: 0.9783
# Epoch 40/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.0856 - val_accuracy: 0.9800
# Epoch 41/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0134 - accuracy: 0.9967 - val_loss: 0.1161 - val_accuracy: 0.9700
# Epoch 42/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.0677 - val_accuracy: 0.9833
# Epoch 43/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0225 - accuracy: 0.9940 - val_loss: 0.1105 - val_accuracy: 0.9733
# Epoch 44/100
# 75/75 [==============================] - 13s 178ms/step - loss: 0.0159 - accuracy: 0.9940 - val_loss: 0.0959 - val_accuracy: 0.9767
# Epoch 45/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0820 - val_accuracy: 0.9867
# Epoch 46/100
# 75/75 [==============================] - 14s 182ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.0415 - val_accuracy: 0.9892
# Epoch 47/100
# 75/75 [==============================] - 13s 175ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.0428 - val_accuracy: 0.9867
# Epoch 48/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0598 - val_accuracy: 0.9875
# Epoch 49/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0611 - val_accuracy: 0.9858
# Epoch 50/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0554 - val_accuracy: 0.9858
# Epoch 51/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0512 - val_accuracy: 0.9858
# Epoch 52/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0206 - accuracy: 0.9944 - val_loss: 0.0775 - val_accuracy: 0.9808
# Epoch 53/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.0827 - val_accuracy: 0.9858
# Epoch 54/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0592 - val_accuracy: 0.9875
# Epoch 55/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.0024 - accuracy: 0.9987 - val_loss: 0.0893 - val_accuracy: 0.9875
# Epoch 56/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0086 - accuracy: 0.9981 - val_loss: 0.1196 - val_accuracy: 0.9817
# Epoch 57/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.0464 - val_accuracy: 0.9908
# Epoch 58/100
# 75/75 [==============================] - 13s 175ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0536 - val_accuracy: 0.9900
# Epoch 59/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0069 - accuracy: 0.9985 - val_loss: 0.0933 - val_accuracy: 0.9833
# Epoch 60/100
# 75/75 [==============================] - 14s 182ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.0380 - val_accuracy: 0.9917
# Epoch 61/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0409 - val_accuracy: 0.9917
# Epoch 62/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0727 - val_accuracy: 0.9842
# Epoch 63/100
# 75/75 [==============================] - 14s 184ms/step - loss: 4.8773e-04 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9850
# Epoch 64/100
# 75/75 [==============================] - 13s 176ms/step - loss: 2.8185e-04 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 0.9850
# Epoch 65/100
# 75/75 [==============================] - 13s 176ms/step - loss: 2.7570e-04 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 0.9867
# Epoch 66/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.0899 - val_accuracy: 0.9808
# Epoch 67/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0515 - val_accuracy: 0.9858
# Epoch 68/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0076 - accuracy: 0.9983 - val_loss: 0.2632 - val_accuracy: 0.9717
# Epoch 69/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0092 - accuracy: 0.9979 - val_loss: 0.0419 - val_accuracy: 0.9867
# Epoch 70/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.0552 - val_accuracy: 0.9867
# Epoch 71/100
# 75/75 [==============================] - 13s 175ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.0637 - val_accuracy: 0.9833
# Epoch 72/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0675 - val_accuracy: 0.9875
# Epoch 73/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.0655 - val_accuracy: 0.9875
# Epoch 74/100
# 75/75 [==============================] - 13s 177ms/step - loss: 5.5923e-04 - accuracy: 0.9998 - val_loss: 0.0564 - val_accuracy: 0.9875
# Epoch 75/100
# 75/75 [==============================] - 14s 182ms/step - loss: 1.1386e-04 - accuracy: 1.0000 - val_loss: 0.0564 - val_accuracy: 0.9892
# Epoch 76/100
# 75/75 [==============================] - 14s 182ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0585 - val_accuracy: 0.9867
# Epoch 77/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.0715 - val_accuracy: 0.9892
# Epoch 78/100
# 75/75 [==============================] - 14s 193ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0999 - val_accuracy: 0.9833
# Epoch 79/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0123 - accuracy: 0.9967 - val_loss: 0.0523 - val_accuracy: 0.9875
# Epoch 80/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0128 - accuracy: 0.9977 - val_loss: 0.0628 - val_accuracy: 0.9908
# Epoch 81/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 0.0756 - val_accuracy: 0.9867
# Epoch 82/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0394 - val_accuracy: 0.9900
# Epoch 83/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.2335 - val_accuracy: 0.9575
# Epoch 84/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0090 - accuracy: 0.9983 - val_loss: 0.0576 - val_accuracy: 0.9892
# Epoch 85/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0666 - val_accuracy: 0.9842
# Epoch 86/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.0432 - val_accuracy: 0.9867
# Epoch 87/100
# 75/75 [==============================] - 14s 183ms/step - loss: 9.5232e-04 - accuracy: 0.9998 - val_loss: 0.0455 - val_accuracy: 0.9867
# Epoch 88/100
# 75/75 [==============================] - 14s 184ms/step - loss: 6.7116e-04 - accuracy: 1.0000 - val_loss: 0.0528 - val_accuracy: 0.9883
# Epoch 89/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.0674 - val_accuracy: 0.9833
# Epoch 90/100
# 75/75 [==============================] - 13s 177ms/step - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.6662 - val_accuracy: 0.8850
# Epoch 91/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0445 - val_accuracy: 0.9892
# Epoch 92/100
# 75/75 [==============================] - 14s 183ms/step - loss: 8.9431e-04 - accuracy: 0.9998 - val_loss: 0.0500 - val_accuracy: 0.9875
# Epoch 93/100
# 75/75 [==============================] - 13s 176ms/step - loss: 0.0092 - accuracy: 0.9977 - val_loss: 0.0817 - val_accuracy: 0.9875
# Epoch 94/100
# 75/75 [==============================] - 16s 209ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0360 - val_accuracy: 0.9908
# Epoch 95/100
# 75/75 [==============================] - 15s 199ms/step - loss: 5.8918e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9892
# Epoch 96/100
# 75/75 [==============================] - 14s 183ms/step - loss: 1.8994e-04 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9908
# Epoch 97/100
# 75/75 [==============================] - 14s 184ms/step - loss: 2.1693e-04 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9908
# Epoch 98/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0329 - val_accuracy: 0.9917
# Epoch 99/100
# 75/75 [==============================] - 13s 177ms/step - loss: 9.6223e-04 - accuracy: 0.9998 - val_loss: 0.0453 - val_accuracy: 0.9875
# Epoch 100/100
# 75/75 [==============================] - 14s 193ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0521 - val_accuracy: 0.9933

# %%
testX_arg = np.argmax(Y_test)
y_pred = np.argmax(e_model_b0.predict(X_test), axis=1)
y_true = np.argmax(Y_test)
print(y_pred)
print(y_pred.shape)
# Out:
# 38/38 [==============================] - 3s 26ms/step
# [0 0 0 ... 5 5 5]
# (1200,)

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
cm = confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[192,   0,   8,   0,   0,   0],
#        [  0, 200,   0,   0,   0,   0],
#        [  0,   0, 200,   0,   0,   0],
#        [  0,   0,   0, 200,   0,   0],
#        [  0,   0,   0,   0, 200,   0],
#        [  0,   0,   0,   0,   0, 200]])

# %%
print(classification_report(Y_test, y_pred,  digits=7,target_names = CATEGORIES))
# Out:
#                       precision    recall  f1-score   support
#
#    Rice___Brown_Spot  1.0000000 0.9600000 0.9795918       200
#   Corn___Common_Rust  1.0000000 1.0000000 1.0000000       200
#       Rice___Healthy  0.9615385 1.0000000 0.9803922       200
#       Corn___Healthy  1.0000000 1.0000000 1.0000000       200
# Potato___Late_Blight  1.0000000 1.0000000 1.0000000       200
#     Potato___Healthy  1.0000000 1.0000000 1.0000000       200
#
#             accuracy                      0.9933333      1200
#            macro avg  0.9935897 0.9933333 0.9933307      1200
#         weighted avg  0.9935897 0.9933333 0.9933307      1200

# %%
import pandas as pd
cm = pd.DataFrame(cm , index = CATEGORIES , columns = CATEGORIES)

# %%
plt.figure(figsize = (20,20))
ct= CATEGORIES
plt.title("Confusion Matrix", fontsize =20)
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = ct,yticklabels = ct)
# Out:
# <Axes: title={'center': 'Confusion Matrix'}>
