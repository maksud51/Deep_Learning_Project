# %%
#pip install tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
name="ZFNET"

# %%
import os
import cv2
import pickle
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array, load_img


np.random.seed(1000)
# ignore information messgaes from tensorflow, but we will receieve error messages
os.environ['TFF_CPP_MIN_LOG_LEVEL'] = '2'

# %matplotlib inline

# %%
import os
import numpy as np
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras import optimizers
from keras.preprocessing import image
from PIL import Image,ImageOps
import cv2
import matplotlib.pyplot as plt
import tensorflow
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, BatchNormalization, ReLU, ELU, Dropout, Conv2D, Dense, MaxPool2D, AvgPool2D, GlobalAvgPool2D, Concatenate
import tensorflow as tf
import tensorflow.keras

from tensorflow.keras import models, layers
from tensorflow.keras.models import Model, model_from_json, Sequential

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, SeparableConv2D, UpSampling2D, BatchNormalization, Input, GlobalAveragePooling2D

from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, RMSprop
from tensorflow.keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
import tensorflow
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, BatchNormalization, ReLU, ELU, Dropout, Conv2D, Dense, MaxPool2D, AvgPool2D, GlobalAvgPool2D, Concatenate

# %%
DATA_DIR = '/content/drive/MyDrive/20K dataset(Equal)/Dataset'  
TRAIN_DATA_DIR = os.path.join(DATA_DIR, 'train')
TEST_DATA_DIR = os.path.join(DATA_DIR, 'test')

# %%
IMG_SIZE = 64
CATEGORIES = []

for i in os.listdir(TRAIN_DATA_DIR):
    CATEGORIES.append(i)
    
print(CATEGORIES)
# Out:
# ['Negative', 'Positive']

# %%
plt.figure(figsize=(15,4))
i=0
for c in CATEGORIES:  
    path = os.path.join(TRAIN_DATA_DIR,c)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.subplot(2,10,i+1)
        plt.imshow(img_array)
        if i%10 == 0:
            plt.ylabel(c)
        plt.xticks([])
        plt.yticks([])
        i += 1
        if i%10 == 0:
            break

plt.tight_layout()        
plt.show()

# %%
training_data = []

for c in CATEGORIES:
    path = os.path.join(TRAIN_DATA_DIR, c) # 'E:/DATASETS/classification/Face Mask Dataset/train/WithMask'
    class_num = CATEGORIES.index(c) # 0
    for img in tqdm(os.listdir(path)):
        try:
            img_array = cv2.imread(os.path.join(path, img))   # read the image
            img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize the image
            training_data.append([img_resized, class_num]) # [ [img, 0], [], [], [], ...., []]
        except WException as e:
            pass
        
print(len(training_data))
# Out:
# 100%|██████████| 8154/8154 [00:31<00:00, 261.50it/s]
# 100%|██████████| 8154/8154 [00:31<00:00, 262.70it/s]
# 16308

# %%
test_data = []

for c in CATEGORIES:
    path = os.path.join(TEST_DATA_DIR, c) 
    class_num = CATEGORIES.index(c) 
    for img in tqdm(os.listdir(path)):
        try:
            img_array = cv2.imread(os.path.join(path, img))   
            img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  
            test_data.append([img_resized, class_num])
        except WException as e:
            pass
        
print(len(test_data))
# Out:
# 100%|██████████| 2038/2038 [00:07<00:00, 267.11it/s]
# 100%|██████████| 2038/2038 [00:08<00:00, 247.33it/s]
# 4076

# %%
X_train = []
Y_train = []

for img, label in training_data:
    X_train.append(img)
    Y_train.append(label)
    
X_train = np.array(X_train).astype('float32').reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y_train = np.array(Y_train)

print(f"X_train= {X_train.shape} Y_train= {Y_train.shape}")
# Out:
# X_train= (16308, 64, 64, 3) Y_train= (16308,)

# %%
X_test = []
Y_test = []

for features,label in test_data:
    X_test.append(features)
    Y_test.append(label)

X_test = np.array(X_test).astype('float32').reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y_test = np.array(Y_test)

print(f"X_test= {X_test.shape} Y_test= {Y_test.shape}")
# Out:
# X_test= (4076, 64, 64, 3) Y_test= (4076,)

# %%
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
model = keras.Sequential([
    
    keras.Input(shape=(64,64,3)),
    
    keras.layers.Conv2D(filters=96, kernel_size=(5,5), strides=(2,2), activation='relu'),
    layers.Dropout(0.2),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2), padding='valid'),
    
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(2,2), activation='relu', padding="same"),
    layers.Dropout(0.2),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2), padding='valid'),
    
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    layers.Dropout(0.3),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(1,1), padding='valid'),
    
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    layers.Dropout(0.3),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(1,1), padding='valid'),
    
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    layers.Dropout(0.3),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(1,1), padding='valid'),
    
    keras.layers.Flatten(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1024,activation='relu'),
    keras.layers.Dense(512,activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(2,activation='softmax') 
])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 30, 30, 96)        7296
#
#  dropout_13 (Dropout)        (None, 30, 30, 96)        0
#
#  batch_normalization_12 (Bat  (None, 30, 30, 96)       384
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 15, 15, 96)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 256)         614656
#
#  dropout_14 (Dropout)        (None, 8, 8, 256)         0
#
#  batch_normalization_13 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 256)        0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 4, 4, 384)         885120
#
#  dropout_15 (Dropout)        (None, 4, 4, 384)         0
#
#  batch_normalization_14 (Bat  (None, 4, 4, 384)        1536
#  chNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 3, 3, 384)        0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 3, 3, 384)         1327488
#
#  dropout_16 (Dropout)        (None, 3, 3, 384)         0
#
#  batch_normalization_15 (Bat  (None, 3, 3, 384)        1536
#  chNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 2, 2, 384)        0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 2, 2, 256)         884992
#
#  dropout_17 (Dropout)        (None, 2, 2, 256)         0
#
#  batch_normalization_16 (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_6 (Dense)             (None, 1024)              263168
#
#  dense_7 (Dense)             (None, 512)               524800
#
#  batch_normalization_17 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_8 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 4,516,098
# Trainable params: 4,512,322
# Non-trainable params: 3,776
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h = model.fit(x=X_train, y=Y_train, epochs=80, validation_data=(X_test, Y_test), batch_size=64)
# Out:
# Epoch 1/80
# 255/255 [==============================] - 7s 23ms/step - loss: 0.7543 - accuracy: 0.5565 - val_loss: 1.0676 - val_accuracy: 0.5000
# Epoch 2/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.5808 - accuracy: 0.6902 - val_loss: 2.7068 - val_accuracy: 0.5012
# Epoch 3/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.4484 - accuracy: 0.7917 - val_loss: 0.7595 - val_accuracy: 0.6008
# Epoch 4/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.3363 - accuracy: 0.8523 - val_loss: 0.5819 - val_accuracy: 0.7478
# Epoch 5/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.2504 - accuracy: 0.8940 - val_loss: 0.3546 - val_accuracy: 0.8530
# Epoch 6/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.1916 - accuracy: 0.9212 - val_loss: 0.5411 - val_accuracy: 0.7659
# Epoch 7/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.1387 - accuracy: 0.9441 - val_loss: 0.3186 - val_accuracy: 0.8575
# Epoch 8/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.1189 - accuracy: 0.9551 - val_loss: 0.4764 - val_accuracy: 0.8145
# Epoch 9/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.1066 - accuracy: 0.9600 - val_loss: 0.2712 - val_accuracy: 0.9097
# Epoch 10/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0811 - accuracy: 0.9694 - val_loss: 0.3039 - val_accuracy: 0.8999
# Epoch 11/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0778 - accuracy: 0.9701 - val_loss: 0.2173 - val_accuracy: 0.9100
# Epoch 12/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0652 - accuracy: 0.9759 - val_loss: 0.1920 - val_accuracy: 0.9284
# Epoch 13/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0629 - accuracy: 0.9770 - val_loss: 0.2728 - val_accuracy: 0.8938
# Epoch 14/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0519 - accuracy: 0.9809 - val_loss: 0.2137 - val_accuracy: 0.9266
# Epoch 15/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0520 - accuracy: 0.9831 - val_loss: 0.2402 - val_accuracy: 0.9119
# Epoch 16/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0501 - accuracy: 0.9814 - val_loss: 0.2234 - val_accuracy: 0.9284
# Epoch 17/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0471 - accuracy: 0.9841 - val_loss: 0.1894 - val_accuracy: 0.9357
# Epoch 18/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0456 - accuracy: 0.9836 - val_loss: 0.4734 - val_accuracy: 0.8658
# Epoch 19/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0441 - accuracy: 0.9854 - val_loss: 0.1865 - val_accuracy: 0.9347
# Epoch 20/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0333 - accuracy: 0.9887 - val_loss: 0.5939 - val_accuracy: 0.8383
# Epoch 21/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0334 - accuracy: 0.9888 - val_loss: 0.2536 - val_accuracy: 0.9107
# Epoch 22/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0373 - accuracy: 0.9872 - val_loss: 0.2690 - val_accuracy: 0.9139
# Epoch 23/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0377 - accuracy: 0.9852 - val_loss: 0.5362 - val_accuracy: 0.8472
# Epoch 24/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0343 - accuracy: 0.9873 - val_loss: 0.2118 - val_accuracy: 0.9129
# Epoch 25/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0293 - accuracy: 0.9895 - val_loss: 0.2287 - val_accuracy: 0.9122
# Epoch 26/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0278 - accuracy: 0.9901 - val_loss: 0.2502 - val_accuracy: 0.9178
# Epoch 27/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0307 - accuracy: 0.9891 - val_loss: 0.5053 - val_accuracy: 0.8312
# Epoch 28/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0232 - accuracy: 0.9926 - val_loss: 0.2331 - val_accuracy: 0.9262
# Epoch 29/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0234 - accuracy: 0.9928 - val_loss: 0.1878 - val_accuracy: 0.9377
# Epoch 30/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0288 - accuracy: 0.9893 - val_loss: 0.3407 - val_accuracy: 0.8908
# Epoch 31/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0237 - accuracy: 0.9921 - val_loss: 0.1644 - val_accuracy: 0.9455
# Epoch 32/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0236 - accuracy: 0.9920 - val_loss: 0.2341 - val_accuracy: 0.9264
# Epoch 33/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0214 - accuracy: 0.9932 - val_loss: 0.1663 - val_accuracy: 0.9443
# Epoch 34/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0238 - accuracy: 0.9918 - val_loss: 0.2590 - val_accuracy: 0.9247
# Epoch 35/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0250 - accuracy: 0.9908 - val_loss: 0.2708 - val_accuracy: 0.9190
# Epoch 36/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0205 - accuracy: 0.9933 - val_loss: 0.2082 - val_accuracy: 0.9392
# Epoch 37/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0229 - accuracy: 0.9925 - val_loss: 0.2959 - val_accuracy: 0.9112
# Epoch 38/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0252 - accuracy: 0.9912 - val_loss: 0.3098 - val_accuracy: 0.9107
# Epoch 39/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0260 - accuracy: 0.9921 - val_loss: 0.1907 - val_accuracy: 0.9438
# Epoch 40/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.2077 - val_accuracy: 0.9350
# Epoch 41/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0220 - accuracy: 0.9927 - val_loss: 0.2158 - val_accuracy: 0.9264
# Epoch 42/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0234 - accuracy: 0.9917 - val_loss: 0.2002 - val_accuracy: 0.9235
# Epoch 43/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.2414 - val_accuracy: 0.9274
# Epoch 44/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.2435 - val_accuracy: 0.9342
# Epoch 45/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0149 - accuracy: 0.9948 - val_loss: 0.2375 - val_accuracy: 0.9352
# Epoch 46/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0169 - accuracy: 0.9947 - val_loss: 0.2773 - val_accuracy: 0.8921
# Epoch 47/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.2135 - val_accuracy: 0.9362
# Epoch 48/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.2831 - val_accuracy: 0.9254
# Epoch 49/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.5213 - val_accuracy: 0.8658
# Epoch 50/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0288 - accuracy: 0.9903 - val_loss: 0.2849 - val_accuracy: 0.9227
# Epoch 51/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 0.1907 - val_accuracy: 0.9441
# Epoch 52/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0112 - accuracy: 0.9960 - val_loss: 0.2283 - val_accuracy: 0.9360
# Epoch 53/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 0.2169 - val_accuracy: 0.9387
# Epoch 54/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.2559 - val_accuracy: 0.9345
# Epoch 55/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.1997 - val_accuracy: 0.9450
# Epoch 56/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0131 - accuracy: 0.9959 - val_loss: 0.2964 - val_accuracy: 0.9215
# Epoch 57/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.2068 - val_accuracy: 0.9419
# Epoch 58/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.2564 - val_accuracy: 0.9330
# Epoch 59/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0152 - accuracy: 0.9953 - val_loss: 0.2380 - val_accuracy: 0.9374
# Epoch 60/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.3311 - val_accuracy: 0.9105
# Epoch 61/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.1972 - val_accuracy: 0.9431
# Epoch 62/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.1775 - val_accuracy: 0.9377
# Epoch 63/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.1754 - val_accuracy: 0.9482
# Epoch 64/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.1926 - val_accuracy: 0.9374
# Epoch 65/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0105 - accuracy: 0.9964 - val_loss: 0.2674 - val_accuracy: 0.9220
# Epoch 66/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0121 - accuracy: 0.9964 - val_loss: 0.2043 - val_accuracy: 0.9392
# Epoch 67/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.3690 - val_accuracy: 0.9188
# Epoch 68/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.3488 - val_accuracy: 0.9146
# Epoch 69/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0107 - accuracy: 0.9959 - val_loss: 0.1669 - val_accuracy: 0.9473
# Epoch 70/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.2940 - val_accuracy: 0.9360
# Epoch 71/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0096 - accuracy: 0.9970 - val_loss: 0.1927 - val_accuracy: 0.9480
# Epoch 72/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.1731 - val_accuracy: 0.9426
# Epoch 73/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.3075 - val_accuracy: 0.9217
# Epoch 74/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.2041 - val_accuracy: 0.9514
# Epoch 75/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.1918 - val_accuracy: 0.9470
# Epoch 76/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.2565 - val_accuracy: 0.9274
# Epoch 77/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.1683 - val_accuracy: 0.9502
# Epoch 78/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.1775 - val_accuracy: 0.9512
# Epoch 79/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.3013 - val_accuracy: 0.9230
# Epoch 80/80
# 255/255 [==============================] - 6s 22ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.2204 - val_accuracy: 0.9468

# %%
import seaborn as sns

# %%
#  "Accuracy"
plt.figure(figsize=[8, 4])
sns.set_theme()
plt.plot(h.history['accuracy'], 'o-',color="blue")
plt.plot(h.history['val_accuracy'] ,'o-', color="magenta")
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
#plt.show()
plt.gca().set_position([0.1, 0.12, 0.8, 0.8])
plt.savefig('/content/drive/MyDrive/Paper_Figure/'+(name)+'_ACCURACY.svg')
#plt.close()

# %%
# "Loss"
plt.figure(figsize=[8, 4])
sns.set_theme()
plt.plot(h.history['loss'],'o-', color="blue")
plt.plot(h.history['val_loss'],'o-', color="magenta")
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
#plt.show()
plt.gca().set_position([0.1, 0.12, 0.8, 0.8])
plt.savefig('/content/drive/MyDrive/Paper_Figure/'+(name)+'_LOSS.svg')

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
train_loss, train_acc=model.evaluate(X_train, Y_train)
print('\nTest Accuracy:', test_acc)
print('\nTest Loss:', test_loss)
print('\nTrain Accuracy:', train_acc)
print('\nTrain Loss:', train_loss)
# Out:
# 128/128 [==============================] - 1s 5ms/step - loss: 0.2204 - accuracy: 0.9468
# 510/510 [==============================] - 2s 5ms/step - loss: 0.0019 - accuracy: 0.9998
#
# Test Accuracy: 0.9467615485191345
#
# Test Loss: 0.2203841358423233
#
# Train Accuracy: 0.9998160600662231
#
# Train Loss: 0.0018549947999417782

# %%
score = model.evaluate(X_test,Y_test,verbose=0)

print("Accuracy: ",np.round(score[1]*100,3),"%")
# Out:
# Accuracy:  94.676 %

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
img_width, img_height = 64, 64
validation_data_dir = '/content/drive/MyDrive/20K dataset(Equal)/Dataset/test'
train_data_dir = '/content/drive/MyDrive/20K dataset(Equal)/Dataset/train'

# %%
IMG_SHAPE = img_height, img_width, 3
classes = 2
batch_size=64

# %%
datagen = ImageDataGenerator(rescale=1./255)
train_generator = datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=64,
    shuffle=True,
    class_mode='categorical')

validation_generator = datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=64,
    shuffle=False,
    class_mode='categorical')
# Out:
# Found 16308 images belonging to 2 classes.
# Found 4076 images belonging to 2 classes.

# %%
num_train_samples = train_generator.samples
num_validation_samples = validation_generator.samples

print('num_train_samples: ' + str(num_train_samples))
print('num_validation_samples: ' + str(num_validation_samples))
# Out:
# num_train_samples: 16308
# num_validation_samples: 4076

# %%
Y_pred = model.predict_generator(validation_generator, num_validation_samples// batch_size+1)
print(Y_pred.shape)
y_pred = np.argmax(Y_pred, axis=1)
y_true= validation_generator.classes

target_names = ['positive', 'Negative']
print(classification_report(y_true, y_pred, target_names=target_names, digits=3))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   """Entry point for launching an IPython kernel.
# (4076, 2)
#               precision    recall  f1-score   support
#
#     positive      0.968     0.915     0.940      2038
#     Negative      0.919     0.970     0.944      2038
#
#     accuracy                          0.942      4076
#    macro avg      0.943     0.942     0.942      4076
# weighted avg      0.943     0.942     0.942      4076

# %%
cm = confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues
                         ):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(12,12))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1]), ):
        plt.text(j, i, cm[i, j, ],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()    
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
import seaborn as sns
import imp
imp.reload(sns)
sns.reset_defaults()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib.font_manager import FontProperties

# plt.figure() 
# prop = FontProperties()
# prop.set_file('Siyamrupali.ttf')

# %%
import itertools
cm_plot_labels = ['Postive', 'Negative']
#sns.set_theme()
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title='Confusion Matrix')
#plt.savefig('./graph/TwoClass_conf_Raw_1.svg')
#plt.savefig('G:/Nazia/BanglaLekha/Comp-graph/cf_val_git_05.png')
plt.savefig('/content/drive/MyDrive/Paper_Figure/'+(name)+'Confusion_Matrix.svg')
# Out:
# Confusion matrix, without normalization
# [[1864  174]
#  [  62 1976]]
