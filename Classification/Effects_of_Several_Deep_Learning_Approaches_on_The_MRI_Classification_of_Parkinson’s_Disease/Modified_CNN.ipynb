# %%
#pip install tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
name="Modified_CNN"

# %%
import os
import cv2
import pickle
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array, load_img


np.random.seed(1000)
# ignore information messgaes from tensorflow, but we will receieve error messages
os.environ['TFF_CPP_MIN_LOG_LEVEL'] = '2'

# %matplotlib inline

# %%
import os
import numpy as np
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras import optimizers
from keras.preprocessing import image
from PIL import Image,ImageOps
import cv2
import matplotlib.pyplot as plt
import tensorflow
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, BatchNormalization, ReLU, ELU, Dropout, Conv2D, Dense, MaxPool2D, AvgPool2D, GlobalAvgPool2D, Concatenate
import tensorflow as tf
import tensorflow.keras

from tensorflow.keras import models, layers
from tensorflow.keras.models import Model, model_from_json, Sequential

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, SeparableConv2D, UpSampling2D, BatchNormalization, Input, GlobalAveragePooling2D

from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, RMSprop
from tensorflow.keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
import tensorflow
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, BatchNormalization, ReLU, ELU, Dropout, Conv2D, Dense, MaxPool2D, AvgPool2D, GlobalAvgPool2D, Concatenate

# %%
DATA_DIR = '/content/drive/MyDrive/20K dataset(Equal)/Dataset'  
TRAIN_DATA_DIR = os.path.join(DATA_DIR, 'train')
TEST_DATA_DIR = os.path.join(DATA_DIR, 'test')

# %%
IMG_SIZE = 64
CATEGORIES = []

for i in os.listdir(TRAIN_DATA_DIR):
    CATEGORIES.append(i)
    
print(CATEGORIES)
# Out:
# ['Negative', 'Positive']

# %%
plt.figure(figsize=(15,4))
i=0
for c in CATEGORIES:  
    path = os.path.join(TRAIN_DATA_DIR,c)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.subplot(2,10,i+1)
        plt.imshow(img_array)
        if i%10 == 0:
            plt.ylabel(c)
        plt.xticks([])
        plt.yticks([])
        i += 1
        if i%10 == 0:
            break

plt.tight_layout()        
plt.show()

# %%
training_data = []

for c in CATEGORIES:
    path = os.path.join(TRAIN_DATA_DIR, c) # 'E:/DATASETS/classification/Face Mask Dataset/train/WithMask'
    class_num = CATEGORIES.index(c) # 0
    for img in tqdm(os.listdir(path)):
        try:
            img_array = cv2.imread(os.path.join(path, img))   # read the image
            img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize the image
            training_data.append([img_resized, class_num]) # [ [img, 0], [], [], [], ...., []]
        except WException as e:
            pass
        
print(len(training_data))
# Out:
# 100%|██████████| 8154/8154 [02:33<00:00, 52.95it/s]
# 100%|██████████| 8154/8154 [02:46<00:00, 49.11it/s]
# 16308

# %%
test_data = []

for c in CATEGORIES:
    path = os.path.join(TEST_DATA_DIR, c) 
    class_num = CATEGORIES.index(c) 
    for img in tqdm(os.listdir(path)):
        try:
            img_array = cv2.imread(os.path.join(path, img))   
            img_resized = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  
            test_data.append([img_resized, class_num])
        except WException as e:
            pass
        
print(len(test_data))
# Out:
# 100%|██████████| 2038/2038 [00:35<00:00, 56.98it/s]
# 100%|██████████| 2038/2038 [00:40<00:00, 50.68it/s]
# 4076

# %%
X_train = []
Y_train = []

for img, label in training_data:
    X_train.append(img)
    Y_train.append(label)
    
X_train = np.array(X_train).astype('float32').reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y_train = np.array(Y_train)

print(f"X_train= {X_train.shape} Y_train= {Y_train.shape}")
# Out:
# X_train= (16308, 64, 64, 3) Y_train= (16308,)

# %%
X_test = []
Y_test = []

for features,label in test_data:
    X_test.append(features)
    Y_test.append(label)

X_test = np.array(X_test).astype('float32').reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y_test = np.array(Y_test)

print(f"X_test= {X_test.shape} Y_test= {Y_test.shape}")
# Out:
# X_test= (4076, 64, 64, 3) Y_test= (4076,)

# %%
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
model = keras.Sequential([
    ## input layer
    keras.Input(shape=(64,64,3)),
    
    ## hidden layer
    layers.Conv2D(filters=32, kernel_size=(5,5), activation='relu'), 
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2,2)),
    
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),

    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),

    layers.Dense(32, activation='relu'),
    layers.BatchNormalization(),
    
    ## output layer
    layers.Dense(2, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 60, 60, 32)        2432
#
#  batch_normalization (BatchN  (None, 60, 60, 32)       128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        36928
#
#  batch_normalization_2 (Batc  (None, 12, 12, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  batch_normalization_5 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 364,834
# Trainable params: 364,066
# Non-trainable params: 768
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
h = model.fit(x=X_train, y=Y_train, epochs=80, validation_data=(X_test, Y_test), batch_size=64)
# Out:
# Epoch 1/80
# 255/255 [==============================] - 14s 16ms/step - loss: 0.4496 - accuracy: 0.7889 - val_loss: 1.1560 - val_accuracy: 0.5000
# Epoch 2/80
# 255/255 [==============================] - 4s 14ms/step - loss: 0.2048 - accuracy: 0.9173 - val_loss: 0.4652 - val_accuracy: 0.7760
# Epoch 3/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.1138 - accuracy: 0.9580 - val_loss: 0.4582 - val_accuracy: 0.8491
# Epoch 4/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0766 - accuracy: 0.9728 - val_loss: 0.2481 - val_accuracy: 0.9134
# Epoch 5/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0599 - accuracy: 0.9779 - val_loss: 0.4193 - val_accuracy: 0.8633
# Epoch 6/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0451 - accuracy: 0.9844 - val_loss: 0.2477 - val_accuracy: 0.9158
# Epoch 7/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0330 - accuracy: 0.9885 - val_loss: 0.3141 - val_accuracy: 0.9139
# Epoch 8/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0468 - accuracy: 0.9827 - val_loss: 0.4422 - val_accuracy: 0.8712
# Epoch 9/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0283 - accuracy: 0.9911 - val_loss: 0.2157 - val_accuracy: 0.9342
# Epoch 10/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0300 - accuracy: 0.9895 - val_loss: 0.2967 - val_accuracy: 0.9109
# Epoch 11/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0228 - accuracy: 0.9922 - val_loss: 0.2841 - val_accuracy: 0.9235
# Epoch 12/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0340 - accuracy: 0.9888 - val_loss: 0.3664 - val_accuracy: 0.8955
# Epoch 13/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0316 - accuracy: 0.9885 - val_loss: 0.2134 - val_accuracy: 0.9367
# Epoch 14/80
# 255/255 [==============================] - 4s 16ms/step - loss: 0.0163 - accuracy: 0.9951 - val_loss: 0.2211 - val_accuracy: 0.9379
# Epoch 15/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0267 - accuracy: 0.9908 - val_loss: 0.3984 - val_accuracy: 0.8992
# Epoch 16/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0233 - accuracy: 0.9915 - val_loss: 0.3784 - val_accuracy: 0.8960
# Epoch 17/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0293 - accuracy: 0.9897 - val_loss: 0.3180 - val_accuracy: 0.9085
# Epoch 18/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0200 - accuracy: 0.9936 - val_loss: 0.1510 - val_accuracy: 0.9563
# Epoch 19/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0234 - accuracy: 0.9918 - val_loss: 0.2190 - val_accuracy: 0.9404
# Epoch 20/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.2109 - val_accuracy: 0.9453
# Epoch 21/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.5530 - val_accuracy: 0.8707
# Epoch 22/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0146 - accuracy: 0.9951 - val_loss: 0.2453 - val_accuracy: 0.9340
# Epoch 23/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0249 - accuracy: 0.9909 - val_loss: 0.2142 - val_accuracy: 0.9433
# Epoch 24/80
# 255/255 [==============================] - 4s 14ms/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.5697 - val_accuracy: 0.8692
# Epoch 25/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0252 - accuracy: 0.9908 - val_loss: 0.2104 - val_accuracy: 0.9453
# Epoch 26/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.1679 - val_accuracy: 0.9507
# Epoch 27/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.3867 - val_accuracy: 0.9102
# Epoch 28/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0136 - accuracy: 0.9952 - val_loss: 0.2130 - val_accuracy: 0.9455
# Epoch 29/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 0.2042 - val_accuracy: 0.9470
# Epoch 30/80
# 255/255 [==============================] - 4s 14ms/step - loss: 0.0160 - accuracy: 0.9953 - val_loss: 0.2354 - val_accuracy: 0.9374
# Epoch 31/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.2426 - val_accuracy: 0.9404
# Epoch 32/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.2232 - val_accuracy: 0.9423
# Epoch 33/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0121 - accuracy: 0.9952 - val_loss: 0.1953 - val_accuracy: 0.9468
# Epoch 34/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.3179 - val_accuracy: 0.9230
# Epoch 35/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.2683 - val_accuracy: 0.9298
# Epoch 36/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.4198 - val_accuracy: 0.9011
# Epoch 37/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0069 - accuracy: 0.9981 - val_loss: 0.1918 - val_accuracy: 0.9529
# Epoch 38/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.4170 - val_accuracy: 0.8967
# Epoch 39/80
# 255/255 [==============================] - 4s 14ms/step - loss: 0.0274 - accuracy: 0.9904 - val_loss: 0.3341 - val_accuracy: 0.9146
# Epoch 40/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0116 - accuracy: 0.9960 - val_loss: 0.2377 - val_accuracy: 0.9414
# Epoch 41/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.1676 - val_accuracy: 0.9630
# Epoch 42/80
# 255/255 [==============================] - 3s 14ms/step - loss: 7.8195e-04 - accuracy: 0.9999 - val_loss: 0.1213 - val_accuracy: 0.9674
# Epoch 43/80
# 255/255 [==============================] - 4s 14ms/step - loss: 5.1581e-04 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9715
# Epoch 44/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.2224 - val_accuracy: 0.9500
# Epoch 45/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.2120 - val_accuracy: 0.9514
# Epoch 46/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.5447 - val_accuracy: 0.8805
# Epoch 47/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.1426 - val_accuracy: 0.9637
# Epoch 48/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.1427 - val_accuracy: 0.9693
# Epoch 49/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.1297 - val_accuracy: 0.9684
# Epoch 50/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.1685 - val_accuracy: 0.9605
# Epoch 51/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.2223 - val_accuracy: 0.9421
# Epoch 52/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.1762 - val_accuracy: 0.9563
# Epoch 53/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.2333 - val_accuracy: 0.9446
# Epoch 54/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.3324 - val_accuracy: 0.9382
# Epoch 55/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0075 - accuracy: 0.9971 - val_loss: 0.1770 - val_accuracy: 0.9637
# Epoch 56/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.1436 - val_accuracy: 0.9679
# Epoch 57/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.1973 - val_accuracy: 0.9620
# Epoch 58/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.2291 - val_accuracy: 0.9522
# Epoch 59/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.2157 - val_accuracy: 0.9485
# Epoch 60/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0117 - accuracy: 0.9957 - val_loss: 0.3912 - val_accuracy: 0.9242
# Epoch 61/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.2015 - val_accuracy: 0.9549
# Epoch 62/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.1433 - val_accuracy: 0.9708
# Epoch 63/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.2504 - val_accuracy: 0.9504
# Epoch 64/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.4957 - val_accuracy: 0.9019
# Epoch 65/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.2043 - val_accuracy: 0.9615
# Epoch 66/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.1720 - val_accuracy: 0.9632
# Epoch 67/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1544 - val_accuracy: 0.9676
# Epoch 68/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.1335 - val_accuracy: 0.9760
# Epoch 69/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.2102 - val_accuracy: 0.9556
# Epoch 70/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.2520 - val_accuracy: 0.9377
# Epoch 71/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0128 - accuracy: 0.9952 - val_loss: 0.2110 - val_accuracy: 0.9590
# Epoch 72/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.1623 - val_accuracy: 0.9639
# Epoch 73/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.1588 - val_accuracy: 0.9627
# Epoch 74/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.1814 - val_accuracy: 0.9615
# Epoch 75/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.2657 - val_accuracy: 0.9455
# Epoch 76/80
# 255/255 [==============================] - 4s 14ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.2706 - val_accuracy: 0.9475
# Epoch 77/80
# 255/255 [==============================] - 3s 13ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.1504 - val_accuracy: 0.9669
# Epoch 78/80
# 255/255 [==============================] - 4s 14ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.2000 - val_accuracy: 0.9585
# Epoch 79/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.3025 - val_accuracy: 0.9369
# Epoch 80/80
# 255/255 [==============================] - 3s 14ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.2893 - val_accuracy: 0.9468

# %%
import seaborn as sns

# %%
#  "Accuracy"
plt.figure(figsize=[8, 4])
sns.set_theme()
plt.plot(h.history['accuracy'], 'o-',color="blue")
plt.plot(h.history['val_accuracy'] ,'o-', color="magenta")
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
#plt.show()
plt.gca().set_position([0.1, 0.12, 0.8, 0.8])
plt.savefig('/content/drive/MyDrive/Paper_Figure/'+(name)+'_ACCURACY.svg')
#plt.close()

# %%
# "Loss"
plt.figure(figsize=[8, 4])
sns.set_theme()
plt.plot(h.history['loss'],'o-', color="blue")
plt.plot(h.history['val_loss'],'o-', color="magenta")
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
#plt.show()
plt.gca().set_position([0.1, 0.12, 0.8, 0.8])
plt.savefig('/content/drive/MyDrive/Paper_Figure/'+(name)+'_LOSS.svg')

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
train_loss, train_acc=model.evaluate(X_train, Y_train)
print('\nTest Accuracy:', test_acc)
print('\nTest Loss:', test_loss)
print('\nTrain Accuracy:', train_acc)
print('\nTrain Loss:', train_loss)
# Out:
# 128/128 [==============================] - 1s 4ms/step - loss: 0.2893 - accuracy: 0.9468
# 510/510 [==============================] - 2s 4ms/step - loss: 0.0084 - accuracy: 0.9972
#
# Test Accuracy: 0.9467615485191345
#
# Test Loss: 0.2893097996711731
#
# Train Accuracy: 0.9971792697906494
#
# Train Loss: 0.008408250287175179

# %%
score = model.evaluate(X_test,Y_test,verbose=0)

print("Accuracy: ",np.round(score[1]*100,3),"%")
# Out:
# Accuracy:  94.676 %

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
img_width, img_height = 64, 64
validation_data_dir = '/content/drive/MyDrive/20K dataset(Equal)/Dataset/test'
train_data_dir = '/content/drive/MyDrive/20K dataset(Equal)/Dataset/train'

# %%
IMG_SHAPE = img_height, img_width, 3
classes = 2
batch_size=64

# %%
datagen = ImageDataGenerator(rescale=1./255)
train_generator = datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=64,
    shuffle=True,
    class_mode='categorical')

validation_generator = datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=64,
    shuffle=False,
    class_mode='categorical')
# Out:
# Found 16308 images belonging to 2 classes.
# Found 4076 images belonging to 2 classes.

# %%
num_train_samples = train_generator.samples
num_validation_samples = validation_generator.samples

print('num_train_samples: ' + str(num_train_samples))
print('num_validation_samples: ' + str(num_validation_samples))
# Out:
# num_train_samples: 16308
# num_validation_samples: 4076

# %%
Y_pred = model.predict_generator(validation_generator, num_validation_samples// batch_size+1)
print(Y_pred.shape)
y_pred = np.argmax(Y_pred, axis=1)
y_true= validation_generator.classes

target_names = ['positive', 'Negative']
print(classification_report(y_true, y_pred, target_names=target_names, digits=3))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   """Entry point for launching an IPython kernel.
# (4076, 2)
#               precision    recall  f1-score   support
#
#     positive      0.941     0.941     0.941      2038
#     Negative      0.941     0.941     0.941      2038
#
#     accuracy                          0.941      4076
#    macro avg      0.941     0.941     0.941      4076
# weighted avg      0.941     0.941     0.941      4076

# %%
cm = confusion_matrix(y_true, y_pred)

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues
                         ):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(12,12))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1]), ):
        plt.text(j, i, cm[i, j, ],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()    
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
import seaborn as sns
import imp
imp.reload(sns)
sns.reset_defaults()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib.font_manager import FontProperties

# plt.figure() 
# prop = FontProperties()
# prop.set_file('Siyamrupali.ttf')

# %%
import itertools
cm_plot_labels = ['Postive', 'Negative']
#sns.set_theme()
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title='Confusion Matrix')
#plt.savefig('./graph/TwoClass_conf_Raw_1.svg')
#plt.savefig('G:/Nazia/BanglaLekha/Comp-graph/cf_val_git_05.png')
plt.savefig('/content/drive/MyDrive/Paper_Figure/'+(name)+'Confusion_Matrix.svg')
# Out:
# Confusion matrix, without normalization
# [[1917  121]
#  [ 121 1917]]
